# %% [markdown]
# Lab
# ==========================================
# Clustering
# ------------------------------------------
# Alessandro D. Gagliardi

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn.datasets as datasets

from sklearn.preprocessing import scale

plt.jet() # set the color map. When your colors are lost, re-run this.

# %% [markdown]
# For our first example, let's create some synthetic easy-to-cluster data:

# %%
X, Y = datasets.make_blobs(centers=4, cluster_std=0.5, random_state=1)

# %%
# x is matrix of variables
# y is classes

# %% [markdown]
# As always, we first *plot* the data to get a feeling of what we're dealing with:

# %%
plt.scatter(X[:,0], X[:,1]);

# %% [markdown]
# The data looks like it may contain four different "types" of data point.
#
# In fact, this is how it was created above.
#
# We can plot this information as well, using color:

# %%
plt.scatter(X[:,0], X[:,1], c=Y);

# %% [markdown]
# However, if you do not know the information in `Y`, you could try to recover it from the data alone.
#
# Using hierarchical clustering, we start with a distance matrix:

# %%
# compute distance matrix
from scipy.spatial.distance import pdist, squareform

# not printed as pretty, but the values are correct
distx = squareform(pdist(X, metric='euclidean'))
distx
# Out:
# array([[ 0.        ,  4.07351377,  1.38489752, ...,  4.20935219,
#          4.83513775,  5.09018246],
#        [ 4.07351377,  0.        ,  5.09606694, ...,  3.60582807,
#          0.77397149,  3.88578556],
#        [ 1.38489752,  5.09606694,  0.        , ...,  4.19184808,
#          5.81665145,  5.10360012],
#        ...,
#        [ 4.20935219,  3.60582807,  4.19184808, ...,  0.        ,
#          3.85038289,  0.91236854],
#        [ 4.83513775,  0.77397149,  5.81665145, ...,  3.85038289,
#          0.        ,  3.95349833],
#        [ 5.09018246,  3.88578556,  5.10360012, ...,  0.91236854,
#          3.95349833,  0.        ]])

# %% [markdown]
# We then use `scipy.cluster.hierarchy.linkage` to create the hierarchy, and `...dendrogram` to plot it.

# %%
# perform clustering and plot the dendrogram
from scipy.cluster.hierarchy import linkage, dendrogram

R = dendrogram(linkage(distx, method='single'), color_threshold=10)

plt.xlabel('points')
plt.ylabel('Height')
plt.suptitle('Cluster Dendrogram', fontweight='bold', fontsize=14);

# %% [markdown]
# `linkage` supports other methods such as [Ward's](http://en.wikipedia.org/wiki/Ward%27s_method):
#
# $$ d(u,v) = \sqrt{\frac{|v|+|s|}
#                        {T}d(v,s)^2
#                 + \frac{|v|+|t|}
#                        {T}d(v,t)^2
#                 + \frac{|v|}
#                        {T}d(s,t)^2}$$

# %%
R = dendrogram(linkage(distx, method='ward'), color_threshold=100)

plt.xlabel('points')
plt.ylabel('Height')
plt.suptitle('Cluster Dendrogram', fontweight='bold', fontsize=14);

# %% [markdown]
# scikit-learn supports [Ward's method](http://en.wikipedia.org/wiki/Ward%27s_method) as an unsupervised learning method. However (as with kMeans), you must specify how many clusters you want to get out:

# %%
from sklearn.cluster import Ward

hierarch = Ward(4)
Y_hat_hier = hierarch.fit(X).labels_

# %% [markdown]
# Now the label assignments should be quite similar to `Y`, up to a different ordering of the colors:

# %%
plt.scatter(X[:,0], X[:,1], c=Y_hat_hier);

# %% [markdown]
# We can do the same using `KMeans`.
#
# Note that `KMeans` takes an optional `random_state` argument but `Ward` does not. This is because hierarchical clustering is deterministic while k-Means involves a random element (for picking initial centroids).

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(4, random_state=1)
Y_hat_kmeans = kmeans.fit(X).labels_

plt.scatter(X[:,0], X[:,1], c=Y_hat_kmeans);

# %% [markdown]
# Often, you're not so much interested in the assignments to the means.
#
# You'll want to have a closer look at the means $\mu$.
#
# The means in $\mu$ can be seen as *representatives* of their respective cluster.

# %%
plt.scatter?

# %%
X
# Out:
# array([[ -7.99387312,  -7.53514609],
#        [-10.10887657,  -4.05372758],
#        [ -6.63043911,  -7.77802228],
#        [ -9.43189781,  -3.19344014],
#        [ -0.78715402,   4.02588642],
#        [ -1.20876455,   4.65773704],
#        [ -5.69462649,  -2.9040391 ],
#        [ -5.60906722,  -3.23243939],
#        [ -6.34301814,  -3.14831255],
#        [ -6.66395167,  -8.12994446],
#        [ -5.78162818,  -2.98201851],
#        [ -6.59825412,  -2.63804201],
#        [ -9.39825356,  -3.86077034],
#        [ -6.26609107,  -3.64979482],
#        [ -6.42800422,  -7.16967723],
#        [ -6.13446323,  -3.12534181],
#        [ -6.02320337,  -2.44217252],
#        [ -7.02597162,  -7.84403797],
#        [ -1.99518297,   4.40015757],
#        [ -1.63415603,   4.08799205],
#        [ -6.64180186,  -8.58298608],
#        [ -7.75144084,  -7.99564841],
#        [ -7.08422994,  -8.96111428],
#        [ -9.91769397,  -3.51526409],
#        [ -0.92850594,   3.37641951],
#        [ -5.99341522,  -2.96841691],
#        [ -5.01063292,  -3.21310285],
#        [ -6.54546988,  -7.05973828],
#        [-10.30771293,  -3.60433253],
#        [ -2.230819  ,   4.23181851],
#        [ -1.82076851,   4.21446269],
#        [ -7.15816707,  -8.20410104],
#        [ -2.00539028,   4.20811311],
#        [-10.10215962,  -3.66003695],
#        [ -6.9486349 ,  -7.8119524 ],
#        [ -2.03313905,   5.25271717],
#        [ -6.66847875,  -8.46499347],
#        [ -6.02719011,  -3.17613704],
#        [-10.18535498,  -4.27271375],
#        [ -6.50417333,  -7.94877784],
#        [ -7.67991125,  -7.87795936],
#        [ -5.86931994,  -2.56656441],
#        [ -5.32246642,  -2.53325711],
#        [ -9.78596533,  -3.91467851],
#        [ -6.69460396,  -8.63007841],
#        [ -1.09267518,   3.85654424],
#        [ -6.80459402,  -8.7253988 ],
#        [-10.33304365,  -3.76456665],
#        [ -6.88960919,  -8.80936981],
#        [ -1.20913193,   4.06462594],
#        [-10.71976941,  -4.20558148],
#        [ -0.82965882,   4.77751195],
#        [ -1.79350395,   4.6716676 ],
#        [ -9.90443181,  -3.74832272],
#        [ -6.15039619,  -3.23710604],
#        [ -7.21994057,  -9.37064699],
#        [ -1.50004036,   4.28180468],
#        [ -1.50947475,   4.23036495],
#        [ -7.6645162 ,  -7.72155545],
#        [-10.22127679,  -3.34109469],
#        [ -5.17944591,  -4.03696592],
#        [ -2.20986949,   4.97885172],
#        [ -9.75345343,  -3.9911344 ],
#        [ -9.89856264,  -3.89384422],
#        [ -6.25296128,  -3.20194258],
#        [ -6.25105681,  -7.98422226],
#        [ -6.91107515,  -2.9320116 ],
#        [ -9.74124759,  -4.10239496],
#        [ -6.33001929,  -3.39746649],
#        [ -1.63845303,   4.69789748],
#        [-10.16963934,  -3.93155012],
#        [ -7.61233811,  -8.06853689],
#        [ -7.19799144,  -8.13692083],
#        [ -6.55594849,  -2.11134642],
#        [ -9.85491884,  -3.51077797],
#        [ -1.75547768,   3.96267539],
#        [-10.15081451,  -3.53936123],
#        [ -6.80014952,  -8.0843775 ],
#        [ -5.93476085,  -3.24868626],
#        [ -1.22685609,   3.25572052],
#        [ -9.79596668,  -3.65655929],
#        [ -8.9049248 ,  -4.65159672],
#        [ -7.15534233,  -8.45518842],
#        [ -9.83989503,  -4.96444916],
#        [ -5.97363613,  -2.87864436],
#        [ -2.00314626,   3.98388705],
#        [ -1.74577401,   3.96756066],
#        [ -1.59948043,   4.71509142],
#        [ -1.72100502,   3.93860515],
#        [ -9.88266514,  -3.57234296],
#        [ -2.21821508,   4.52369772],
#        [ -5.94527087,  -3.90250463],
#        [ -1.56410216,   5.45661744],
#        [ -9.5782208 ,  -3.48779751],
#        [ -9.93680187,  -3.38860659],
#        [ -7.07719066,  -8.54080891],
#        [ -6.05411355,  -3.13886308],
#        [ -6.533343  ,  -3.58729887],
#        [-10.37491147,  -3.32691447],
#        [ -6.47523487,  -2.67678265]])

# %%
plt.scatter(X[:,0], X[:,1], c=Y_hat_kmeans, alpha=0.4)
mu = kmeans.cluster_centers_
plt.scatter(mu[:,0], mu[:,1], s=100, c=np.unique(Y_hat_kmeans))
print mu
# Out:
# [[-6.03878328 -3.07717032]
#  [-1.61042978  4.31273712]
#  [-7.00367521 -8.15564814]
#  [-9.93193834 -3.80607436]]

# %% [markdown]
# 1-2 Pairs
# =========
#
# 1. Follow the steps below to:
#     - Read `samsungData.csv` and drop `Unnamed: 0` from the data set.
#     - Load data for `subject 1`
#     - Plot the first two variables to see how they relate to the six activities provided.
# 2. Try hierarchical clustering on the first three variables and compare that to the activities.
#     - Try both single linkage and Ward's method.
# 3. Try hierarchical clustering on variables 9 and 10 and do the same.
#     - Try Ward's, single, and complete linkage methods.
# 4. Try using all columns (except `subject` and `activity`). This time scale your values first.
# 5. Try `KMeans` where `n_clusters = 6` and compare the clusters to the `activity` column.

# %%
samsungData = pd.read_csv('samsungData.csv')
samsungData = samsungData.drop(['Unnamed: 0'], axis=1)

# %%
samsungData.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  tBodyAcc-max()-Y  tBodyAcc-max()-Z  \
# 0         -0.923527         -0.934724         -0.567378         -0.744413
# 1         -0.957686         -0.943068         -0.557851         -0.818409
# 2         -0.977469         -0.938692         -0.557851         -0.818409
# 3         -0.989302         -0.938692         -0.576159         -0.829711
# 4         -0.990441         -0.942469         -0.569174         -0.824705
#
#    tBodyAcc-min()-X  tBodyAcc-min()-Y  tBodyAcc-min()-Z  tBodyAcc-sma()  \
# 0          0.852947          0.685845          0.814263       -0.965523
# 1          0.849308          0.685845          0.822637       -0.981930
# 2          0.843609          0.682401          0.839344       -0.983478
# 3          0.843609          0.682401          0.837869       -0.986093
# 4          0.849095          0.683250          0.837869       -0.992653
#
#    tBodyAcc-energy()-X  tBodyAcc-energy()-Y  tBodyAcc-energy()-Z  \
# 0            -0.999945            -0.999863            -0.994612
# 1            -0.999991            -0.999788            -0.998405
# 2            -0.999969            -0.999660            -0.999470
# 3            -0.999976            -0.999736            -0.999504
# 4            -0.999991            -0.999856            -0.999757
#
#    tBodyAcc-iqr()-X
# 0         -0.994231 ...
# 1         -0.999150 ...
# 2         -0.997130 ...
# 3         -0.997180 ...
# 4         -0.998004 ...
#
# [5 rows x 563 columns]

# %% [markdown]
# A quick look on the column names and the type of activities in the data:

# %%
samsungData.columns[:12]
# Out:
# Index([u'tBodyAcc-mean()-X', u'tBodyAcc-mean()-Y', u'tBodyAcc-mean()-Z', u'tBodyAcc-std()-X', u'tBodyAcc-std()-Y', u'tBodyAcc-std()-Z', u'tBodyAcc-mad()-X', u'tBodyAcc-mad()-Y', u'tBodyAcc-mad()-Z', u'tBodyAcc-max()-X', u'tBodyAcc-max()-Y', u'tBodyAcc-max()-Z'], dtype='object')

# %%
samsungData['activity'].value_counts()
# Out:
# laying      1407
# standing    1374
# sitting     1286
# walk        1226
# walkup      1073
# walkdown     986
# dtype: int64

# %%
samsungData['activity'].head(10)
# Out:
# 0    standing
# 1    standing
# 2    standing
# 3    standing
# 4    standing
# 5    standing
# 6    standing
# 7    standing
# 8    standing
# 9    standing
# Name: activity, dtype: object

# %% [markdown]
# The scatter plots below show the first and second variable/feature vectors for subject number 1, colour coded by activity. We see that almost all activities have the first and second variable values around zero, except for LAYING, which is spread throughout the y-axis.
#
# The conclusion from these plots is that we can't really classify the activities based on the two variables, since their values are very close to each other.

# %%
subj1 = samsungData[samsungData['subject'] == 1]

numericActivity = subj1.groupby('activity')

cols = {'laying' : 'b',
        'sitting' : 'g',
        'standing' : 'r',
        'walk' : 'c',
        'walkdown' : 'm',
        'walkup' : 'y'}

f, (ax1, ax2) = plt.subplots(ncols=2)
f.set_size_inches(10, 5)

for act, df in numericActivity:
    ax1.scatter(df.index, df.ix[:,0], c=cols[act], label=act)
    ax2.scatter(df.index, df.ix[:,1], c=cols[act], label=act)

ax1.set_ylabel(samsungData.columns[0])
ax2.set_ylabel(samsungData.columns[1])
ax2.legend(loc='lower right')

f.tight_layout();

# %%
subject_1 = samsungData[samsungData['subject'] == 1]
firstthree = scale(subject_1.ix[:,1:4])

# %%
firstthree.shape
# Out:
# (347, 3)

# %%
# compute distance matrix
from scipy.spatial.distance import pdist, squareform

# not printed as pretty, but the values are correct
dist_firstthree = squareform(pdist(firstthree, metric='euclidean'))
dist_firstthree
# Out:
# array([[ 0.        ,  0.14588405,  0.25930125, ...,  2.83264766,
#          2.72006943,  2.74192054],
#        [ 0.14588405,  0.        ,  0.14649298, ...,  2.78152659,
#          2.681613  ,  2.75175796],
#        [ 0.25930125,  0.14649298,  0.        , ...,  2.72405663,
#          2.66148716,  2.78785212],
#        ...,
#        [ 2.83264766,  2.78152659,  2.72405663, ...,  0.        ,
#          0.73771531,  1.78099522],
#        [ 2.72006943,  2.681613  ,  2.66148716, ...,  0.73771531,
#          0.        ,  1.11256237],
#        [ 2.74192054,  2.75175796,  2.78785212, ...,  1.78099522,
#          1.11256237,  0.        ]])

# %%
dist_firstthree.shape
# Out:
# (347, 347)

# %%
# perform clustering and plot the dendrogram
from scipy.cluster.hierarchy import linkage, dendrogram

R = dendrogram(linkage(dist_firstthree, method='single'), color_threshold=4)

plt.xlabel('points')
plt.ylabel('Height')
plt.suptitle('Cluster Dendrogram', fontweight='bold', fontsize=14);

# %%
# perform clustering and plot the dendrogram
from scipy.cluster.hierarchy import linkage, dendrogram

R = dendrogram(linkage(dist_firstthree, method='ward'), color_threshold=30)

plt.xlabel('points')
plt.ylabel('Height')
plt.suptitle('Cluster Dendrogram', fontweight='bold', fontsize=14);

# %%
nineten = scale(subject_1.ix[:,9:11])

# %%
# compute distance matrix
from scipy.spatial.distance import pdist, squareform

# not printed as pretty, but the values are correct
dist_nineten = squareform(pdist(nineten, metric='euclidean'))
dist_nineten
# Out:
# array([[ 0.        ,  0.04254147,  0.03989653, ...,  3.31879972,
#          3.44822518,  3.44822518],
#        [ 0.04254147,  0.        ,  0.00880345, ...,  3.30774354,
#          3.43962726,  3.43962726],
#        [ 0.03989653,  0.00880345,  0.        , ...,  3.3008058 ,
#          3.43238033,  3.43238033],
#        ...,
#        [ 3.31879972,  3.30774354,  3.3008058 , ...,  0.        ,
#          0.23942155,  0.23942155],
#        [ 3.44822518,  3.43962726,  3.43238033, ...,  0.23942155,
#          0.        ,  0.        ],
#        [ 3.44822518,  3.43962726,  3.43238033, ...,  0.23942155,
#          0.        ,  0.        ]])

# %%
# perform clustering and plot the dendrogram
from scipy.cluster.hierarchy import linkage, dendrogram

R = dendrogram(linkage(dist_nineten, method='single'), color_threshold=2)

plt.xlabel('points')
plt.ylabel('Height')
plt.suptitle('Cluster Dendrogram', fontweight='bold', fontsize=14);

# %%
# perform clustering and plot the dendrogram
from scipy.cluster.hierarchy import linkage, dendrogram

R = dendrogram(linkage(dist_nineten, method='ward'), color_threshold=10)

plt.xlabel('points')
plt.ylabel('Height')
plt.suptitle('Cluster Dendrogram', fontweight='bold', fontsize=14);

# %%
alldata = scale(subject_1.ix[:,:-2])

# %%
# compute distance matrix
from scipy.spatial.distance import pdist, squareform

# not printed as pretty, but the values are correct
dist_alldata = squareform(pdist(alldata, metric='euclidean'))
dist_alldata
# Out:
# array([[  0.        ,  18.82260475,  20.14858399, ...,  54.94681968,
#          48.93043457,  53.46415589],
#        [ 18.82260475,   0.        ,  10.93279133, ...,  52.64325727,
#          45.33771724,  50.19130398],
#        [ 20.14858399,  10.93279133,   0.        , ...,  52.37673141,
#          45.25219126,  50.09194512],
#        ...,
#        [ 54.94681968,  52.64325727,  52.37673141, ...,   0.        ,
#          24.62083989,  24.5264432 ],
#        [ 48.93043457,  45.33771724,  45.25219126, ...,  24.62083989,
#           0.        ,  23.15501716],
#        [ 53.46415589,  50.19130398,  50.09194512, ...,  24.5264432 ,
#          23.15501716,   0.        ]])

# %%
# perform clustering and plot the dendrogram
from scipy.cluster.hierarchy import linkage, dendrogram

R = dendrogram(linkage(dist_alldata, method='single'), color_threshold=30)

plt.xlabel('points')
plt.ylabel('Height')
plt.suptitle('Cluster Dendrogram', fontweight='bold', fontsize=14);

# %%
# perform clustering and plot the dendrogram
from scipy.cluster.hierarchy import linkage, dendrogram

R = dendrogram(linkage(dist_alldata, method='ward'), color_threshold=10)

plt.xlabel('points')
plt.ylabel('Height')
plt.suptitle('Cluster Dendrogram', fontweight='bold', fontsize=14);

# %%
firstthree[:,0:2]
# Out:
# array([[ -3.85276171e-02,  -3.33562536e-01],
#        [  3.64353504e-02,  -2.08640669e-01],
#        [ -2.25642195e-02,  -7.47532637e-02],
#        [ -1.52536926e-01,  -2.05477739e-01],
#        [  3.33645850e-02,  -1.00046050e-01],
#        [  1.58286135e-01,   3.60522909e-02],
#        [ -2.59155071e-02,  -2.89699873e-02],
#        [ -2.35299116e-01,  -2.33135868e-01],
#        [ -6.66421247e-02,  -1.71777939e-01],
#        [  1.60941217e-01,   2.37009997e-02],
#        [  1.07637433e-01,   5.86665305e-02],
#        [ -6.06700306e-02,  -4.74672952e-03],
#        [ -4.08552969e-02,  -6.50367265e-02],
#        [  6.92063564e-02,   1.44990609e-02],
#        [  8.76177368e-01,   6.14664272e-01],
#        [ -9.11454954e-02,  -1.89474211e-01],
#        [  6.75159270e-02,  -1.19840781e-01],
#        [  8.45682131e-02,   1.96369243e-02],
#        [  1.68808453e-03,  -1.78671229e-02],
#        [  2.54497595e-02,  -4.76987834e-02],
#        [  7.68175933e-02,  -4.19365061e-04],
#        [  6.07726364e-03,   1.65662393e-02],
#        [ -5.72521883e-02,  -3.93400883e-02],
#        [  1.12677058e-02,  -1.75119888e-02],
#        [  1.23294153e-01,   6.61630804e-02],
#        [  7.27150167e-02,   1.66327936e-02],
#        [  5.39179582e-03,   1.42420279e-02],
#        [  4.00643961e+00,   2.27103510e+00],
#        [ -3.69774519e-01,  -5.07524584e-01],
#        [ -2.28900445e-02,   2.82481267e-02],
#        [  1.01156010e+00,  -2.09868331e-01],
#        [  3.73310218e+00,   1.77563720e+00],
#        [  3.31218571e+00,   1.65172852e+00],
#        [  2.71302714e-01,  -5.72427996e-01],
#        [ -1.10730067e-01,  -1.18375653e-01],
#        [  1.80800698e-01,   2.45599238e-01],
#        [  2.41966016e-01,  -9.06331217e-03],
#        [  4.19803782e-02,  -3.17839057e-02],
#        [  9.59686324e-02,   2.51001055e-02],
#        [  1.55268915e-01,  -2.25512187e-02],
#        [  2.22885429e-02,  -2.68012470e-02],
#        [  8.07423174e-02,  -1.53452451e-02],
#        [  4.68003682e-02,  -3.53888891e-02],
#        [  7.81531283e-02,  -5.80305491e-02],
#        [  1.16460766e-01,  -2.19333280e-02],
#        [  1.88251219e+00,  -1.18753512e+01],
#        [  5.51969907e-01,  -5.43400606e+00],
#        [  6.04300183e-03,  -1.65045833e-01],
#        [  2.19459390e-01,   1.04499067e+00],
#        [  3.68967299e-01,   1.65725429e+00],
#        [  4.07135532e-03,  -4.50114393e-03],
#        [ -8.61107080e-02,  -3.62219246e-01],
#        [  4.59172948e-03,  -1.63537711e-01],
#        [ -1.80107375e-01,  -9.90680084e-01],
#        [ -4.67842339e-01,  -2.29899157e+00],
#        [ -8.57876433e-02,  -7.80066550e-01],
#        [ -8.46885823e-02,   5.72980798e-01],
#        [  4.70266813e-01,   2.59894089e-01],
#        [ -1.22844992e-02,   4.86658556e-01],
#        [  3.20362112e-02,   7.01704104e-01],
#        [  3.87669872e-02,   6.53439294e-02],
#        [ -3.43210498e-01,  -4.11038732e-01],
#        [  2.24922801e-02,  -2.03979468e-01],
#        [  4.12963602e-01,  -2.62457589e-01],
#        [ -1.05333250e-02,  -1.48131390e+00],
#        [ -3.61061365e-01,  -3.13148451e-01],
#        [ -1.41627213e-01,  -1.90945994e-01],
#        [  4.70814377e-01,  -2.36256723e-02],
#        [  4.28040024e-01,   7.20879666e-01],
#        [  1.73852814e-01,   7.91006198e-01],
#        [ -2.34078161e-01,   2.31650868e-01],
#        [ -2.80120570e-01,  -2.11706296e-01],
#        [ -6.26349985e-02,  -5.70925864e-01],
#        [  2.94270801e-01,  -2.67611026e-01],
#        [  1.48716556e-03,  -2.69773776e-01],
#        [ -4.24018724e-01,  -5.71397202e-01],
#        [ -2.83958240e-01,  -1.78701590e-01],
#        [ -6.04482953e-01,  -6.72905234e-02],
#        [  6.25093198e-01,   1.29895833e+00],
#        [  8.80496788e-01,   5.97515969e-01],
#        [ -9.66118465e-02,   3.46217489e-01],
#        [  1.65296442e-02,   2.91811963e-01],
#        [ -9.84370262e-02,  -3.00946907e-01],
#        [ -5.97067496e-03,  -2.92291645e-01],
#        [  7.51201365e-01,   2.03787273e-01],
#        [  3.10881957e-01,  -2.27957140e-01],
#        [ -7.01391758e-01,  -4.16303049e-01],
#        [ -3.98086298e-01,  -1.75346717e-01],
#        [  2.01227564e-01,   2.64201446e-02],
#        [  5.02928563e-01,   2.70637281e-01],
#        [ -6.82659813e-01,  -1.96459665e+00],
#        [  5.24261766e-02,   5.78865134e-02],
#        [  2.33475493e-01,   3.78292045e-01],
#        [  4.95463454e-01,  -1.91841017e-01],
#        [  3.68375154e-01,  -4.74209734e-01],
#        [  1.99630413e-01,  -1.64995917e-01],
#        [ -4.71306372e-01,   4.08577818e-02],
#        [ -4.76043130e-01,  -1.27430108e-01],
#        [  5.00674714e-01,   2.54189008e-02],
#        [  3.43376469e-01,   1.62762461e-01],
#        [ -4.02343764e-02,   2.46507785e-01],
#        [ -2.00609024e-01,  -7.26301675e-03],
#        [ -3.97608370e-01,   1.21790412e-01],
#        [ -7.19325148e-02,   1.32708721e-01],
#        [  7.72707783e-01,  -1.27910471e+00],
#        [  2.86893339e-01,  -4.72031277e-01],
#        [  1.35976141e+00,   3.33476749e-01],
#        [  1.99227019e-01,  -8.20340590e-01],
#        [ -8.96184913e-01,  -2.11993012e-01],
#        [  4.53402125e-01,  -5.11038654e-01],
#        [  6.47101537e-01,  -7.39475179e-01],
#        [ -9.54962505e-01,   7.94408004e-01],
#        [ -9.23142961e-02,   7.75444084e-02],
#        [ -4.10641987e-01,  -1.65670911e-01],
#        [ -1.53147481e-01,   6.06987081e-01],
#        [  3.64114276e-01,   4.34783852e-01],
#        [ -2.31733688e-01,  -7.70593723e-02],
#        [  1.56278934e-01,  -1.37370933e-01],
#        [  1.32007289e-01,  -6.11745916e-01],
#        [ -3.11986138e-01,  -2.54713324e-01],
#        [ -1.09230202e+00,   7.33995787e-01],
#        [ -2.80193360e-01,  -6.95781298e-02],
#        [  4.96409091e-01,   1.97604480e-01],
#        [  9.02654405e-02,   2.05626862e-01],
#        [  5.38702106e-02,   5.02511990e-01],
#        [  2.99470962e-01,   5.59553416e-01],
#        [ -4.83569590e-01,  -1.21165878e-01],
#        [ -2.12931675e-01,  -3.86452886e-01],
#        [  2.61909153e-01,  -1.71366900e-01],
#        [ -8.08297232e-01,   1.20053397e+00],
#        [ -7.05774651e-02,  -2.14125945e-03],
#        [  5.29245965e-01,   4.07681997e-02],
#        [  6.78133375e-01,   1.28076484e-02],
#        [  3.55592045e-01,   1.87604993e-01],
#        [ -4.94088397e-02,   7.37180519e-01],
#        [ -1.63933697e-01,   7.10147601e-02],
#        [ -2.26243942e-01,  -2.47367307e-02],
#        [ -5.31042638e-01,   5.21160415e-01],
#        [  9.45383096e-01,   1.93186741e+00],
#        [ -1.27036604e-01,   2.85669834e-01],
#        [ -6.47011645e-01,  -6.85503454e-01],
#        [ -1.19627135e-01,  -6.12837674e-01],
#        [  8.70154952e-01,  -1.08454502e+00],
#        [ -5.21193806e-01,   7.32588400e-02],
#        [ -1.13261484e-01,   1.19986717e+00],
#        [  9.74236366e-01,   7.89125731e-01],
#        [  2.86455620e-01,   4.97498783e-01],
#        [ -4.25958560e-01,   4.65236345e-01],
#        [ -7.30934761e-01,  -6.32183429e-01],
#        [ -1.89799510e-01,  -6.07998905e-01],
#        [ -8.45766475e-02,   7.41362927e-02],
#        [  3.49885312e-01,   3.29745618e-01],
#        [  1.25358587e-01,   9.54469695e-01],
#        [  5.74126295e-01,   3.70153552e-01],
#        [  6.77476417e-01,  -7.35918115e-01]])

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(2, random_state=1)
Y_hat_kmeans = kmeans.fit(firstthree[:,0:2]).labels_

plt.scatter(firstthree[:,1], firstthree[:,2], c=Y_hat_kmeans);

# %%
firsthree[:,0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-80b934c3c552> in <module>()
# ----> 1 firsthree[:,0]
#
# NameError: name 'firsthree' is not defined

# %% [markdown]
# Homework
# =========
# Try hierarchical and k-Means clustering using the iris data set.

# %%
from sklearn.datasets import load_iris
